# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('3.1 GO1.csv')
df.head()
# Out:
#                                       Date           Author Verified Helpful  \
# 0  Reviewed in Canada on February 15, 2021  Amazon Customer      yes       -
# 1   Reviewed in Canada on October 14, 2020    Richard PIChÉ      yes       -
# 2    Reviewed in Canada on January 9, 2021              Den      yes       -
# 3  Reviewed in Canada on February 15, 2021            Zohar      yes       -
# 4    Reviewed in Canada on August 19, 2020         Jason R.        -     yes
#
#                                                Title  \
# 0                               Would purchase again
# 1                                       Bonne caméra
# 2                                        Easy to use
# 3                                                Wow
# 4  Nice design, good clear video quality, motion ...
#
#                                                 Body  Rating Images Videos  \
# 0  The perfect camera for inside and outside your...       5      -      -
# ...

# %%
# Out:
# 0                                 Would purchase again
# 1                                         Bonne caméra
# 2                                          Easy to use
# 3                                                  Wow
# 4    Nice design, good clear video quality, motion ...
# Name: Title, dtype: object
